# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 731

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
    time.sleep(2)
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        print(f"{i} sleeping...")
        time.sleep(90)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | khuzhir
# Processing Record 4 of Set 1 | geraldton
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | muleba
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | viedma
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 1 | oga
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | talnakh
# Processing Record 17 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | iwanai
# Processing Record 20 of Set 1 | balurghat
# Processing Record 21 of Set 1 | faanui
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | labuhan
# Processing Record 24 of Set 1 | upernavik
# Processing Record 25 of Set 1 | micheweni
# Processing Record 26 of Set 1 | najran
# Processing Record 27 of Set 1 | mount gambier
# Processing Record 28 of Set 1 | gat
# Processing Record 29 of Set 1 | ouargaye
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | isfana
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | fairbanks
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | tosya
# Processing Record 40 of Set 1 | veraval
# Processing Record 41 of Set 1 | marzuq
# Processing Record 42 of Set 1 | guerrero negro
# Processing Record 43 of Set 1 | east london
# Processing Record 44 of Set 1 | albany
# Processing Record 45 of Set 1 | arrifes
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | omsukchan
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | guane
# Processing Record 50 of Set 1 | lagoa
# 50 sleeping...
# Processing Record 1 of Set 2 | pisco
# Processing Record 2 of Set 2 | wynyard
# Processing Record 3 of Set 2 | tautira
# Processing Record 4 of Set 2 | huanren
# Processing Record 5 of Set 2 | alappuzha
# Processing Record 6 of Set 2 | coahuayana
# Processing Record 7 of Set 2 | belmonte
# Processing Record 8 of Set 2 | wexford
# Processing Record 9 of Set 2 | kushima
# Processing Record 10 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 2 | awbari
# Processing Record 12 of Set 2 | fortuna
# Processing Record 13 of Set 2 | hambantota
# Processing Record 14 of Set 2 | dingle
# Processing Record 15 of Set 2 | henties bay
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | algeciras
# Processing Record 18 of Set 2 | victoria
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 2 | orlik
# Processing Record 22 of Set 2 | klyuchi
# Processing Record 23 of Set 2 | port lincoln
# Processing Record 24 of Set 2 | tezu
# Processing Record 25 of Set 2 | bengkulu
# Processing Record 26 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 2 | ambon
# Processing Record 28 of Set 2 | saint-philippe
# Processing Record 29 of Set 2 | dicabisagan
# Processing Record 30 of Set 2 | maceio
# Processing Record 31 of Set 2 | moron
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | khatanga
# Processing Record 34 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 2 | fort nelson
# Processing Record 36 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 2 | ahipara
# Processing Record 38 of Set 2 | saldanha
# Processing Record 39 of Set 2 | garwa
# Processing Record 40 of Set 2 | barrow
# Processing Record 41 of Set 2 | rosarito
# Processing Record 42 of Set 2 | deputatskiy
# Processing Record 43 of Set 2 | georgetown
# Processing Record 44 of Set 2 | constitucion
# Processing Record 45 of Set 2 | airai
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | tuktoyaktuk
# Processing Record 48 of Set 2 | souillac
# Processing Record 49 of Set 2 | hami
# Processing Record 50 of Set 2 | wennigsen
# 100 sleeping...
# Processing Record 1 of Set 3 | fengrun
# Processing Record 2 of Set 3 | klaksvik
# Processing Record 3 of Set 3 | ambilobe
# Processing Record 4 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 3 | coquimbo
# Processing Record 6 of Set 3 | beringovskiy
# Processing Record 7 of Set 3 | qaanaaq
# Processing Record 8 of Set 3 | atuona
# Processing Record 9 of Set 3 | tuatapere
# Processing Record 10 of Set 3 | provideniya
# Processing Record 11 of Set 3 | kansk
# Processing Record 12 of Set 3 | vila velha
# Processing Record 13 of Set 3 | kununurra
# Processing Record 14 of Set 3 | saint anthony
# Processing Record 15 of Set 3 | marmora
# Processing Record 16 of Set 3 | polovinnoye
# Processing Record 17 of Set 3 | tweed
# Processing Record 18 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 3 | sagarejo
# Processing Record 20 of Set 3 | westport
# Processing Record 21 of Set 3 | saint george
# Processing Record 22 of Set 3 | palestine
# Processing Record 23 of Set 3 | mahebourg
# Processing Record 24 of Set 3 | sao filipe
# Processing Record 25 of Set 3 | hailun
# Processing Record 26 of Set 3 | butaritari
# Processing Record 27 of Set 3 | liverpool
# Processing Record 28 of Set 3 | soyo
# Processing Record 29 of Set 3 | hermanus
# Processing Record 30 of Set 3 | arraial do cabo
# Processing Record 31 of Set 3 | yar-sale
# Processing Record 32 of Set 3 | kodiak
# Processing Record 33 of Set 3 | sistranda
# Processing Record 34 of Set 3 | buenaventura
# Processing Record 35 of Set 3 | castro
# Processing Record 36 of Set 3 | acapulco
# Processing Record 37 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 3 | corn island
# Processing Record 39 of Set 3 | kismayo
# Processing Record 40 of Set 3 | muncar
# Processing Record 41 of Set 3 | bowen
# Processing Record 42 of Set 3 | egvekinot
# Processing Record 43 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 3 | carnarvon
# Processing Record 45 of Set 3 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 46 of Set 3 | mackay
# Processing Record 47 of Set 3 | hirara
# Processing Record 48 of Set 3 | esperance
# Processing Record 49 of Set 3 | hue
# Processing Record 50 of Set 3 | samarai
# 150 sleeping...
# Processing Record 1 of Set 4 | bata
# Processing Record 2 of Set 4 | nemuro
# Processing Record 3 of Set 4 | fuyu
# Processing Record 4 of Set 4 | mahon
# Processing Record 5 of Set 4 | lorengau
# Processing Record 6 of Set 4 | sitka
# Processing Record 7 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 4 | garachine
# Processing Record 9 of Set 4 | ivybridge
# Processing Record 10 of Set 4 | ancud
# Processing Record 11 of Set 4 | katsuura
# Processing Record 12 of Set 4 | campbell river
# Processing Record 13 of Set 4 | itarema
# Processing Record 14 of Set 4 | longyearbyen
# Processing Record 15 of Set 4 | lumphat
# Processing Record 16 of Set 4 | khartoum
# Processing Record 17 of Set 4 | laguna
# Processing Record 18 of Set 4 | obihiro
# Processing Record 19 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 4 | nanortalik
# Processing Record 21 of Set 4 | port moresby
# Processing Record 22 of Set 4 | alofi
# Processing Record 23 of Set 4 | yusva
# City not found. Skipping...
# Processing Record 24 of Set 4 | naze
# Processing Record 25 of Set 4 | saint-augustin
# Processing Record 26 of Set 4 | mamou
# Processing Record 27 of Set 4 | ventspils
# Processing Record 28 of Set 4 | ovalle
# Processing Record 29 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 4 | daru
# Processing Record 31 of Set 4 | cayenne
# Processing Record 32 of Set 4 | ixtapa
# Processing Record 33 of Set 4 | bethel
# Processing Record 34 of Set 4 | san patricio
# Processing Record 35 of Set 4 | mejicanos
# Processing Record 36 of Set 4 | ngunguru
# Processing Record 37 of Set 4 | diego de almagro
# Processing Record 38 of Set 4 | port hardy
# Processing Record 39 of Set 4 | pangody
# Processing Record 40 of Set 4 | norman wells
# Processing Record 41 of Set 4 | culpeper
# Processing Record 42 of Set 4 | miles city
# Processing Record 43 of Set 4 | huntington
# Processing Record 44 of Set 4 | lompoc
# Processing Record 45 of Set 4 | grand-lahou
# Processing Record 46 of Set 4 | tasiilaq
# Processing Record 47 of Set 4 | mehamn
# Processing Record 48 of Set 4 | nikolskoye
# Processing Record 49 of Set 4 | kaitangata
# Processing Record 50 of Set 4 | mabaruma
# 200 sleeping...
# Processing Record 1 of Set 5 | avera
# Processing Record 2 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 3 of Set 5 | torbay
# Processing Record 4 of Set 5 | chuy
# Processing Record 5 of Set 5 | nizhniy tsasuchey
# Processing Record 6 of Set 5 | ahtopol
# Processing Record 7 of Set 5 | baturaja
# Processing Record 8 of Set 5 | vaini
# Processing Record 9 of Set 5 | vanimo
# Processing Record 10 of Set 5 | manavgat
# Processing Record 11 of Set 5 | iqaluit
# Processing Record 12 of Set 5 | hasaki
# Processing Record 13 of Set 5 | beloha
# Processing Record 14 of Set 5 | ponta do sol
# Processing Record 15 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 16 of Set 5 | andenes
# Processing Record 17 of Set 5 | broken hill
# Processing Record 18 of Set 5 | requena
# Processing Record 19 of Set 5 | malibu
# Processing Record 20 of Set 5 | brae
# Processing Record 21 of Set 5 | kloulklubed
# Processing Record 22 of Set 5 | puerto del rosario
# Processing Record 23 of Set 5 | peace river
# Processing Record 24 of Set 5 | abu samrah
# Processing Record 25 of Set 5 | coihaique
# Processing Record 26 of Set 5 | tyazhinskiy
# Processing Record 27 of Set 5 | cidreira
# Processing Record 28 of Set 5 | faya
# Processing Record 29 of Set 5 | okhotsk
# Processing Record 30 of Set 5 | ilulissat
# Processing Record 31 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 5 | sturlic
# Processing Record 33 of Set 5 | riyadh
# Processing Record 34 of Set 5 | bakel
# Processing Record 35 of Set 5 | nabire
# Processing Record 36 of Set 5 | lac-megantic
# Processing Record 37 of Set 5 | boa vista
# Processing Record 38 of Set 5 | key west
# Processing Record 39 of Set 5 | tambun
# Processing Record 40 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 5 | joacaba
# Processing Record 42 of Set 5 | pilar
# Processing Record 43 of Set 5 | takahashi
# Processing Record 44 of Set 5 | gushikawa
# Processing Record 45 of Set 5 | sciacca
# Processing Record 46 of Set 5 | dunedin
# Processing Record 47 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 5 | wamba
# Processing Record 49 of Set 5 | broome
# Processing Record 50 of Set 5 | luderitz
# 250 sleeping...
# Processing Record 1 of Set 6 | taft
# Processing Record 2 of Set 6 | bambous virieux
# Processing Record 3 of Set 6 | heihe
# Processing Record 4 of Set 6 | xuddur
# Processing Record 5 of Set 6 | canton
# Processing Record 6 of Set 6 | sidney
# Processing Record 7 of Set 6 | powell river
# Processing Record 8 of Set 6 | khasan
# Processing Record 9 of Set 6 | tuymazy
# Processing Record 10 of Set 6 | isangel
# Processing Record 11 of Set 6 | grindavik
# Processing Record 12 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 6 | khrebtovaya
# Processing Record 14 of Set 6 | codajas
# Processing Record 15 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 6 | bilma
# Processing Record 17 of Set 6 | san cristobal
# Processing Record 18 of Set 6 | alice springs
# Processing Record 19 of Set 6 | narsaq
# Processing Record 20 of Set 6 | kampong thum
# Processing Record 21 of Set 6 | shingu
# Processing Record 22 of Set 6 | wanning
# Processing Record 23 of Set 6 | sibolga
# Processing Record 24 of Set 6 | vidim
# Processing Record 25 of Set 6 | mlonggo
# Processing Record 26 of Set 6 | araouane
# Processing Record 27 of Set 6 | roswell
# Processing Record 28 of Set 6 | iki-burul
# Processing Record 29 of Set 6 | kommunisticheskiy
# Processing Record 30 of Set 6 | obo
# Processing Record 31 of Set 6 | oyon
# Processing Record 32 of Set 6 | tiksi
# Processing Record 33 of Set 6 | wattegama
# Processing Record 34 of Set 6 | saskylakh
# Processing Record 35 of Set 6 | vieques
# Processing Record 36 of Set 6 | latung
# Processing Record 37 of Set 6 | vestmannaeyjar
# Processing Record 38 of Set 6 | yakeshi
# Processing Record 39 of Set 6 | havre-saint-pierre
# Processing Record 40 of Set 6 | vrangel
# Processing Record 41 of Set 6 | matara
# Processing Record 42 of Set 6 | le port
# Processing Record 43 of Set 6 | ribeira grande
# Processing Record 44 of Set 6 | borogontsy
# Processing Record 45 of Set 6 | taungdwingyi
# Processing Record 46 of Set 6 | tadine
# Processing Record 47 of Set 6 | keetmanshoop
# Processing Record 48 of Set 6 | pinega
# Processing Record 49 of Set 6 | salalah
# Processing Record 50 of Set 6 | manoel urbano
# 300 sleeping...
# Processing Record 1 of Set 7 | batagay
# Processing Record 2 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 7 | chapleau
# Processing Record 4 of Set 7 | mizdah
# Processing Record 5 of Set 7 | walvis bay
# Processing Record 6 of Set 7 | mirador
# Processing Record 7 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 7 | agadez
# Processing Record 9 of Set 7 | sola
# Processing Record 10 of Set 7 | bien hoa
# Processing Record 11 of Set 7 | gaoua
# Processing Record 12 of Set 7 | cherskiy
# Processing Record 13 of Set 7 | fukue
# Processing Record 14 of Set 7 | kavaratti
# Processing Record 15 of Set 7 | wageningen
# Processing Record 16 of Set 7 | ribas do rio pardo
# Processing Record 17 of Set 7 | diamantino
# Processing Record 18 of Set 7 | na wa
# Processing Record 19 of Set 7 | yulara
# Processing Record 20 of Set 7 | gamboula
# Processing Record 21 of Set 7 | udachnyy
# Processing Record 22 of Set 7 | codrington
# Processing Record 23 of Set 7 | saint-paul
# Processing Record 24 of Set 7 | shahrud
# Processing Record 25 of Set 7 | areia branca
# Processing Record 26 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 27 of Set 7 | bafia
# Processing Record 28 of Set 7 | pangnirtung
# Processing Record 29 of Set 7 | tutoia
# Processing Record 30 of Set 7 | bure
# Processing Record 31 of Set 7 | shenzhen
# Processing Record 32 of Set 7 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 33 of Set 7 | hobyo
# Processing Record 34 of Set 7 | north platte
# Processing Record 35 of Set 7 | teya
# Processing Record 36 of Set 7 | kedrovyy
# Processing Record 37 of Set 7 | punta cardon
# Processing Record 38 of Set 7 | odesa
# Processing Record 39 of Set 7 | darhan
# Processing Record 40 of Set 7 | hofn
# Processing Record 41 of Set 7 | soissons
# Processing Record 42 of Set 7 | san jose de rio tinto
# Processing Record 43 of Set 7 | kongolo
# Processing Record 44 of Set 7 | wanderlandia
# City not found. Skipping...
# Processing Record 45 of Set 7 | dikson
# Processing Record 46 of Set 7 | concord
# Processing Record 47 of Set 7 | uribia
# Processing Record 48 of Set 7 | popondetta
# Processing Record 49 of Set 7 | gorontalo
# Processing Record 50 of Set 7 | college
# 350 sleeping...
# Processing Record 1 of Set 8 | stromness
# Processing Record 2 of Set 8 | chokurdakh
# Processing Record 3 of Set 8 | san quintin
# Processing Record 4 of Set 8 | muroto
# Processing Record 5 of Set 8 | husavik
# Processing Record 6 of Set 8 | ishigaki
# Processing Record 7 of Set 8 | jaumave
# Processing Record 8 of Set 8 | honningsvag
# Processing Record 9 of Set 8 | tilichiki
# Processing Record 10 of Set 8 | stornoway
# Processing Record 11 of Set 8 | jambi
# Processing Record 12 of Set 8 | port blair
# Processing Record 13 of Set 8 | hervey bay
# Processing Record 14 of Set 8 | kiama
# Processing Record 15 of Set 8 | langatian
# Processing Record 16 of Set 8 | kupang
# Processing Record 17 of Set 8 | neuquen
# Processing Record 18 of Set 8 | yashkino
# Processing Record 19 of Set 8 | kruisfontein
# Processing Record 20 of Set 8 | filingue
# Processing Record 21 of Set 8 | cortez
# Processing Record 22 of Set 8 | iisaku
# Processing Record 23 of Set 8 | varkkallai
# Processing Record 24 of Set 8 | bilibino
# Processing Record 25 of Set 8 | muli
# Processing Record 26 of Set 8 | zverinogolovskoye
# Processing Record 27 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 8 | cabo san lucas
# Processing Record 29 of Set 8 | felidhoo
# City not found. Skipping...
# Processing Record 30 of Set 8 | safaqis
# City not found. Skipping...
# Processing Record 31 of Set 8 | lasa
# Processing Record 32 of Set 8 | naberera
# Processing Record 33 of Set 8 | sur
# Processing Record 34 of Set 8 | chapais
# Processing Record 35 of Set 8 | kabelvag
# Processing Record 36 of Set 8 | kamenka
# Processing Record 37 of Set 8 | hay river
# Processing Record 38 of Set 8 | necochea
# Processing Record 39 of Set 8 | krasnoselkup
# Processing Record 40 of Set 8 | sokolo
# Processing Record 41 of Set 8 | anadyr
# Processing Record 42 of Set 8 | kamwenge
# Processing Record 43 of Set 8 | nouadhibou
# Processing Record 44 of Set 8 | jahrom
# City not found. Skipping...
# Processing Record 45 of Set 8 | rawson
# Processing Record 46 of Set 8 | inhambane
# Processing Record 47 of Set 8 | chumikan
# Processing Record 48 of Set 8 | severo-kurilsk
# Processing Record 49 of Set 8 | pevek
# Processing Record 50 of Set 8 | one hundred mile house
# City not found. Skipping...
# 400 sleeping...
# Processing Record 1 of Set 9 | christchurch
# Processing Record 2 of Set 9 | soe
# Processing Record 3 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 4 of Set 9 | ibiapina
# Processing Record 5 of Set 9 | chimore
# Processing Record 6 of Set 9 | starychi
# Processing Record 7 of Set 9 | tigil
# Processing Record 8 of Set 9 | clarksburg
# Processing Record 9 of Set 9 | makueni
# Processing Record 10 of Set 9 | suntar
# Processing Record 11 of Set 9 | kansanshi
# Processing Record 12 of Set 9 | buraydah
# Processing Record 13 of Set 9 | hamilton
# Processing Record 14 of Set 9 | raga
# Processing Record 15 of Set 9 | oktyabrskiy
# Processing Record 16 of Set 9 | rennes
# Processing Record 17 of Set 9 | vryburg
# Processing Record 18 of Set 9 | namibe
# Processing Record 19 of Set 9 | dong xoai
# Processing Record 20 of Set 9 | pecanha
# Processing Record 21 of Set 9 | gweta
# Processing Record 22 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 23 of Set 9 | mazara del vallo
# Processing Record 24 of Set 9 | harper
# Processing Record 25 of Set 9 | rafaela
# Processing Record 26 of Set 9 | olinda
# Processing Record 27 of Set 9 | peniche
# Processing Record 28 of Set 9 | deer lake
# Processing Record 29 of Set 9 | sabinopolis
# Processing Record 30 of Set 9 | inirida
# Processing Record 31 of Set 9 | basco
# Processing Record 32 of Set 9 | merauke
# Processing Record 33 of Set 9 | rajpur
# Processing Record 34 of Set 9 | berlevag
# Processing Record 35 of Set 9 | atar
# Processing Record 36 of Set 9 | warrnambool
# Processing Record 37 of Set 9 | trinidad
# Processing Record 38 of Set 9 | churapcha
# Processing Record 39 of Set 9 | tsienyane
# City not found. Skipping...
# Processing Record 40 of Set 9 | pedernales
# Processing Record 41 of Set 9 | palkonda
# Processing Record 42 of Set 9 | vanavara
# Processing Record 43 of Set 9 | khurianwala
# City not found. Skipping...
# Processing Record 44 of Set 9 | oyama
# Processing Record 45 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 46 of Set 9 | lagunas
# Processing Record 47 of Set 9 | montepuez
# Processing Record 48 of Set 9 | aksay
# Processing Record 49 of Set 9 | toamasina
# Processing Record 50 of Set 9 | zhigansk
# 450 sleeping...
# Processing Record 1 of Set 10 | ostrovnoy
# Processing Record 2 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 10 | morgan city
# Processing Record 4 of Set 10 | abha
# Processing Record 5 of Set 10 | palenque
# Processing Record 6 of Set 10 | komsomolskiy
# Processing Record 7 of Set 10 | muisne
# Processing Record 8 of Set 10 | storforshei
# Processing Record 9 of Set 10 | cabedelo
# Processing Record 10 of Set 10 | goderich
# Processing Record 11 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 13 of Set 10 | flin flon
# Processing Record 14 of Set 10 | pundaguitan
# Processing Record 15 of Set 10 | montrose
# Processing Record 16 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 17 of Set 10 | lata
# Processing Record 18 of Set 10 | osinki
# Processing Record 19 of Set 10 | clyde river
# Processing Record 20 of Set 10 | santa leopoldina
# Processing Record 21 of Set 10 | batemans bay
# Processing Record 22 of Set 10 | ocu
# Processing Record 23 of Set 10 | shumskiy
# Processing Record 24 of Set 10 | skibbereen
# Processing Record 25 of Set 10 | honiara
# Processing Record 26 of Set 10 | santa cruz cabralia
# Processing Record 27 of Set 10 | sao joao da barra
# Processing Record 28 of Set 10 | banepa
# Processing Record 29 of Set 10 | flinders
# Processing Record 30 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 10 | utinga
# Processing Record 32 of Set 10 | kot samaba
# Processing Record 33 of Set 10 | sept-iles
# Processing Record 34 of Set 10 | phultala
# Processing Record 35 of Set 10 | gorno-altaysk
# Processing Record 36 of Set 10 | dudinka
# Processing Record 37 of Set 10 | leua
# Processing Record 38 of Set 10 | margate
# Processing Record 39 of Set 10 | zabol
# Processing Record 40 of Set 10 | vilyuysk
# Processing Record 41 of Set 10 | shieli
# Processing Record 42 of Set 10 | aksha
# Processing Record 43 of Set 10 | aalestrup
# City not found. Skipping...
# Processing Record 44 of Set 10 | xacmaz
# Processing Record 45 of Set 10 | tazovskiy
# Processing Record 46 of Set 10 | wagar
# Processing Record 47 of Set 10 | tiznit
# Processing Record 48 of Set 10 | nanakuli
# Processing Record 49 of Set 10 | abrau-dyurso
# Processing Record 50 of Set 10 | kyzyl-suu
# 500 sleeping...
# Processing Record 1 of Set 11 | kotel
# Processing Record 2 of Set 11 | haines junction
# Processing Record 3 of Set 11 | tabanan
# Processing Record 4 of Set 11 | kahului
# Processing Record 5 of Set 11 | asosa
# Processing Record 6 of Set 11 | padang
# Processing Record 7 of Set 11 | kaliua
# Processing Record 8 of Set 11 | diu
# Processing Record 9 of Set 11 | lazaro cardenas
# Processing Record 10 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 11 of Set 11 | general cepeda
# Processing Record 12 of Set 11 | etchoropo
# Processing Record 13 of Set 11 | watertown
# Processing Record 14 of Set 11 | soubre
# Processing Record 15 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 11 | te anau
# Processing Record 17 of Set 11 | mapiripan
# Processing Record 18 of Set 11 | bac lieu
# Processing Record 19 of Set 11 | dzaoudzi
# Processing Record 20 of Set 11 | bosaso
# Processing Record 21 of Set 11 | kayes
# Processing Record 22 of Set 11 | sena madureira
# Processing Record 23 of Set 11 | mattru
# Processing Record 24 of Set 11 | smithers
# Processing Record 25 of Set 11 | lahijan
# Processing Record 26 of Set 11 | zhezkazgan
# Processing Record 27 of Set 11 | pochutla
# Processing Record 28 of Set 11 | la ronge
# Processing Record 29 of Set 11 | sumbe
# Processing Record 30 of Set 11 | rach gia
# Processing Record 31 of Set 11 | vadso
# Processing Record 32 of Set 11 | marana
# Processing Record 33 of Set 11 | leningradskiy
# Processing Record 34 of Set 11 | santa fe
# Processing Record 35 of Set 11 | carndonagh
# Processing Record 36 of Set 11 | whitianga
# Processing Record 37 of Set 11 | daloa
# Processing Record 38 of Set 11 | moerai
# Processing Record 39 of Set 11 | yatou
# Processing Record 40 of Set 11 | caucaia
# Processing Record 41 of Set 11 | san vicente
# Processing Record 42 of Set 11 | emba
# Processing Record 43 of Set 11 | marienburg
# Processing Record 44 of Set 11 | fort myers beach
# Processing Record 45 of Set 11 | nuuk
# Processing Record 46 of Set 11 | kaya
# Processing Record 47 of Set 11 | kyra
# Processing Record 48 of Set 11 | pangai
# Processing Record 49 of Set 11 | buala
# Processing Record 50 of Set 11 | catuday
# 550 sleeping...
# Processing Record 1 of Set 12 | bonavista
# Processing Record 2 of Set 12 | chiang klang
# Processing Record 3 of Set 12 | marica
# Processing Record 4 of Set 12 | santa cruz
# Processing Record 5 of Set 12 | homer
# Processing Record 6 of Set 12 | palauig
# Processing Record 7 of Set 12 | kungurtug
# Processing Record 8 of Set 12 | meulaboh
# Processing Record 9 of Set 12 | metkovic
# Processing Record 10 of Set 12 | ulvila
# Processing Record 11 of Set 12 | asyut
# Processing Record 12 of Set 12 | qasigiannguit
# Processing Record 13 of Set 12 | karratha
# Processing Record 14 of Set 12 | songea
# Processing Record 15 of Set 12 | lixourion
# Processing Record 16 of Set 12 | kirensk
# Processing Record 17 of Set 12 | hualmay
# Processing Record 18 of Set 12 | evensk
# Processing Record 19 of Set 12 | falmouth
# Processing Record 20 of Set 12 | pangkalanbuun
# Processing Record 21 of Set 12 | burns lake
# Processing Record 22 of Set 12 | arlit
# Processing Record 23 of Set 12 | sangar
# Processing Record 24 of Set 12 | srandakan
# Processing Record 25 of Set 12 | ust-maya
# Processing Record 26 of Set 12 | lakhipur
# Processing Record 27 of Set 12 | madison heights
# Processing Record 28 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 29 of Set 12 | sisimiut
# Processing Record 30 of Set 12 | pemangkat
# Processing Record 31 of Set 12 | hampden
# Processing Record 32 of Set 12 | grants pass
# Processing Record 33 of Set 12 | kavkazskaya
# Processing Record 34 of Set 12 | kenai
# Processing Record 35 of Set 12 | contamana
# Processing Record 36 of Set 12 | la ferte-bernard
# Processing Record 37 of Set 12 | itatiaia
# Processing Record 38 of Set 12 | conde
# Processing Record 39 of Set 12 | talara
# Processing Record 40 of Set 12 | puerto madero
# Processing Record 41 of Set 12 | uige
# Processing Record 42 of Set 12 | adelaide
# Processing Record 43 of Set 12 | canatlan
# Processing Record 44 of Set 12 | metu
# Processing Record 45 of Set 12 | ternate
# Processing Record 46 of Set 12 | harmanli
# Processing Record 47 of Set 12 | poum
# Processing Record 48 of Set 12 | ndola
# Processing Record 49 of Set 12 | bagdarin
# Processing Record 50 of Set 12 | chicama
# 600 sleeping...
# Processing Record 1 of Set 13 | krasnokamensk
# Processing Record 2 of Set 13 | segezha
# Processing Record 3 of Set 13 | kaniama
# Processing Record 4 of Set 13 | lavrentiya
# Processing Record 5 of Set 13 | breznik
# Processing Record 6 of Set 13 | san borja
# Processing Record 7 of Set 13 | atchison
# Processing Record 8 of Set 13 | srednekolymsk
# Processing Record 9 of Set 13 | ballina
# Processing Record 10 of Set 13 | alexandria
# Processing Record 11 of Set 13 | bandarbeyla
# Processing Record 12 of Set 13 | takoradi
# Processing Record 13 of Set 13 | wenatchee
# Processing Record 14 of Set 13 | tabas
# Processing Record 15 of Set 13 | rocha
# Processing Record 16 of Set 13 | morondava
# Processing Record 17 of Set 13 | vardo
# Processing Record 18 of Set 13 | bria
# Processing Record 19 of Set 13 | misratah
# Processing Record 20 of Set 13 | harij
# Processing Record 21 of Set 13 | callaway
# Processing Record 22 of Set 13 | buritizeiro
# Processing Record 23 of Set 13 | sipe sipe
# Processing Record 24 of Set 13 | yantal
# Processing Record 25 of Set 13 | marktoberdorf
# Processing Record 26 of Set 13 | sao gotardo
# Processing Record 27 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 28 of Set 13 | wawa
# Processing Record 29 of Set 13 | colares
# Processing Record 30 of Set 13 | emerald
# Processing Record 31 of Set 13 | sioux lookout
# Processing Record 32 of Set 13 | palaikastron
# Processing Record 33 of Set 13 | pocone
# Processing Record 34 of Set 13 | qaqortoq
# Processing Record 35 of Set 13 | simao
# Processing Record 36 of Set 13 | nizwa
# Processing Record 37 of Set 13 | medicine hat
# Processing Record 38 of Set 13 | pombas
# Processing Record 39 of Set 13 | rabo de peixe
# Processing Record 40 of Set 13 | mahanoro
# Processing Record 41 of Set 13 | valley
# Processing Record 42 of Set 13 | muskogee
# Processing Record 43 of Set 13 | lamu
# Processing Record 44 of Set 13 | kavieng
# Processing Record 45 of Set 13 | akkudah
# City not found. Skipping...
# Processing Record 46 of Set 13 | sunland park
# Processing Record 47 of Set 13 | sayabec
# City not found. Skipping...
# Processing Record 48 of Set 13 | jiujiang
# Processing Record 49 of Set 13 | kitgum
# Processing Record 50 of Set 13 | santa rosa
# 650 sleeping...
# Processing Record 1 of Set 14 | yerbogachen
# Processing Record 2 of Set 14 | cukai
# Processing Record 3 of Set 14 | sao jose da coroa grande
# Processing Record 4 of Set 14 | lufilufi
# Processing Record 5 of Set 14 | mujiayingzi
# Processing Record 6 of Set 14 | grand gaube
# Processing Record 7 of Set 14 | qinhuangdao
# Processing Record 8 of Set 14 | tura
# Processing Record 9 of Set 14 | addi ugri
# City not found. Skipping...
# Processing Record 10 of Set 14 | huntsville
# Processing Record 11 of Set 14 | malanville
# Processing Record 12 of Set 14 | ndago
# Processing Record 13 of Set 14 | williams lake
# Processing Record 14 of Set 14 | ketchikan
# Processing Record 15 of Set 14 | brigantine
# Processing Record 16 of Set 14 | baykalsk
# Processing Record 17 of Set 14 | saint-pierre
# Processing Record 18 of Set 14 | granville
# Processing Record 19 of Set 14 | sampit
# Processing Record 20 of Set 14 | jalu
# Processing Record 21 of Set 14 | ngawi
# Processing Record 22 of Set 14 | sao joao de pirabas
# Processing Record 23 of Set 14 | mezen
# Processing Record 24 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 25 of Set 14 | monroe
# Processing Record 26 of Set 14 | nome
# Processing Record 27 of Set 14 | sarangani
# Processing Record 28 of Set 14 | bajo baudo
# City not found. Skipping...
# Processing Record 29 of Set 14 | charlestown
# Processing Record 30 of Set 14 | garmsar
# Processing Record 31 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 14 | linqiong
# Processing Record 33 of Set 14 | leiyang
# Processing Record 34 of Set 14 | osoyoos
# Processing Record 35 of Set 14 | svetlogorsk
# Processing Record 36 of Set 14 | ukiah
# Processing Record 37 of Set 14 | north bend
# Processing Record 38 of Set 14 | ziro
# Processing Record 39 of Set 14 | lowestoft
# Processing Record 40 of Set 14 | alta floresta
# Processing Record 41 of Set 14 | qarchi gak
# Processing Record 42 of Set 14 | dunmore east
# Processing Record 43 of Set 14 | tornio
# Processing Record 44 of Set 14 | caceres
# Processing Record 45 of Set 14 | samfya
# Processing Record 46 of Set 14 | marrakesh
# Processing Record 47 of Set 14 | koungheul
# Processing Record 48 of Set 14 | pouebo
# Processing Record 49 of Set 14 | mount isa
# Processing Record 50 of Set 14 | upata
# 700 sleeping...
# Processing Record 1 of Set 15 | lexington
# Processing Record 2 of Set 15 | bintulu
# Processing Record 3 of Set 15 | luocheng
# Processing Record 4 of Set 15 | ushtobe
# Processing Record 5 of Set 15 | balsas
# Processing Record 6 of Set 15 | valverde del camino
# Processing Record 7 of Set 15 | abu dhabi
# Processing Record 8 of Set 15 | nelson bay
# Processing Record 9 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 10 of Set 15 | san ramon
# Processing Record 11 of Set 15 | ust-ilimsk
# Processing Record 12 of Set 15 | vestmanna
# Processing Record 13 of Set 15 | kawasaki
# Processing Record 14 of Set 15 | temirtau
# Processing Record 15 of Set 15 | olafsvik
# Processing Record 16 of Set 15 | panguna
# Processing Record 17 of Set 15 | camargo
# Processing Record 18 of Set 15 | ewa beach
# Processing Record 19 of Set 15 | pacific grove
# Processing Record 20 of Set 15 | muros
# Processing Record 21 of Set 15 | piacabucu
# Processing Record 22 of Set 15 | itaituba
# Processing Record 23 of Set 15 | touros
# Processing Record 24 of Set 15 | trairi
# Processing Record 25 of Set 15 | bathsheba
# Processing Record 26 of Set 15 | los llanos de aridane
# Processing Record 27 of Set 15 | urengoy
# Processing Record 28 of Set 15 | novopokrovka
# Processing Record 29 of Set 15 | olavarria
# Processing Record 30 of Set 15 | brattvag
# Processing Record 31 of Set 15 | guelengdeng
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 674

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Punta Arenas      CL -53.1500  -70.9167     44.71        76          75
# 1        Khuzhir      RU  53.1939  107.3397     37.29        62          20
# 2      Geraldton      AU -28.7667  114.6000     63.01        48         100
# 3        Ushuaia      AR -54.8000  -68.3000     44.26        76          40
# 4     Bredasdorp      ZA -34.5322   20.0403     49.35        92           0
# 5         Muleba      TZ  -1.8397   31.6544     69.10        68          93
# 6      Cape Town      ZA -33.9258   18.4232     61.38        74          20
# 7         Viedma      AR -40.8135  -62.9967     59.94        63           0
# 8  Mar Del Plata      AR -38.0023  -57.5575     60.10        90           0
# 9            Oga      IT  46.4631   10.3470     47.08        81           6
#
#    Wind Speed Current Description
# 0       13.80       broken clouds
# 1        3.67          few clouds
# 2        9.22     overcast clouds
# 3       14.97    scattered clouds
# 4        7.14           clear sky
# 5        4.23     overcast clouds
# 6        4.61          few clouds
# 7       21.14           clear sky
# 8        8.05           clear sky
# 9        3.40           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_order]

# Display sample data
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.1500  -70.9167     44.71        76          75
# 1       Khuzhir      RU  53.1939  107.3397     37.29        62          20
# 2     Geraldton      AU -28.7667  114.6000     63.01        48         100
# 3       Ushuaia      AR -54.8000  -68.3000     44.26        76          40
# 4    Bredasdorp      ZA -34.5322   20.0403     49.35        92           0
#
#    Wind Speed Current Description
# 0       13.80       broken clouds
# 1        3.67          few clouds
# 2        9.22     overcast clouds
# 3       14.97    scattered clouds
# 4        7.14           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
